# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
# Read CSV file
gdp_csv = ("../Data/GDP_2020-2023_quarterly_cleaned.csv")
gdp_df = pd.read_csv(gdp_csv)

# %%
gdp_df
# Out:
#    GeoFips        GeoName     2020:Q1     2020:Q2     2020:Q3     2020:Q4  \
# 0        0  United States  21727657.0  19935444.0  21684551.0  22068767.0
# 1     6000     California   3118522.7   2871237.9   3126987.5   3190272.4
# 2    12000        Florida   1152589.9   1066451.9   1166652.6   1182323.3
# 3    36000       New York   1821606.8   1660253.4   1790068.9   1821550.1
# 4    48000          Texas   1840874.8   1676440.7   1819976.6   1871282.8
# 5    53000     Washington    619251.6    584351.8    637585.2    639342.9
#
#       2021:Q1     2021:Q2     2021:Q3     2021:Q4     2022:Q1     2022:Q2  \
# 0  22656793.0  23368861.0  23921991.0  24777038.0  25215491.0  25805791.0
# 1   3279904.9   3376467.2   3465519.5   3573941.6   3591071.1   3641685.3
# 2   1220392.1   1276526.3   1320150.4   1377455.9   1400023.1   1442829.2
# 3   1840547.4   1897462.8   1938860.2   2016782.7   2025436.9   2029181.6
# 4   1957009.4   2045172.0   2120880.3   2232827.4   2323836.7   2433824.2
# ...
